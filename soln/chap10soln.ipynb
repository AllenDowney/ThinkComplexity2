# %% [markdown]
# # Flocks, Herds, and Traffic Jams
#
# Code examples from [Think Complexity, 2nd edition](https://thinkcomplex.com).
#
# Copyright 2016 Allen Downey, [MIT License](http://opensource.org/licenses/MIT)

# %%
from __future__ import print_function, division

# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

import thinkplot
from thinkstats2 import RandomSeed

from Cell2D import Cell2DViewer

from matplotlib import rc
rc('animation', html='jshtml')

# %% [markdown]
# Here's the `Driver` class from Chapter 10.

# %%
class Driver:
    
    def __init__(self, loc, speed=4):
        """Initialize the attributes.
        
        loc: position on track, in miles
        speed: speed in miles per hour
        """
        self.start = loc
        self.loc = loc
        self.speed = speed
        
    def choose_acceleration(self, dist):
        """Chooses acceleration based on distance.
        
        dist: distance from the car in front
        
        returns: acceleration
        """
        return 1
        
    def set_odometer(self):
        self.start = self.loc
        
    def read_odometer(self):
        return self.loc - self.start

# %% [markdown]
# And the Highway.

# %%
class Highway:
    
    max_acc = 1
    min_acc = -10
    speed_limit = 40
    
    def __init__(self, n=10, length=1000, eps=0, constructor=Driver):
        """Initializes the attributes.
        
        n: number of drivers
        length: length of the track
        eps: variability in speed
        constructor: function used to instantiate drivers
        """
        self.length = length
        self.eps = eps
        self.crashes = 0

        # create the drivers
        locs = np.linspace(0, length, n, endpoint=False)
        self.drivers = [constructor(loc) for loc in locs]
        
        # and link them up
        for i in range(n):
            j = (i+1) % n
            self.drivers[i].next = self.drivers[j]
            
    def step(self):
        """Performs one time step."""
        for driver in self.drivers:
            self.move(driver)
            
    def move(self, driver):
        """Updates `driver`.
        
        driver: Driver object
        """
        # get the distance to the next driver
        dist = self.distance(driver)

        # let the driver choose acceleration
        acc = driver.choose_acceleration(dist)
        acc = min(acc, self.max_acc)
        acc = max(acc, self.min_acc)
        speed = driver.speed + acc
            
        # add random noise to speed
        speed *= np.random.uniform(1-self.eps, 1+self.eps)
        
        # keep it nonnegative and under the speed limit
        speed = max(speed, 0)
        speed = min(speed, self.speed_limit)
        
        # if current speed would collide with next driver, stop
        if speed > dist:
            speed = 0
            self.crashes += 1
            
        # update speed and loc
        driver.speed = speed
        driver.loc += speed
            
    def distance(self, driver):
        """Distance from `driver` to next driver.
        
        driver: Driver object
        """
        dist = driver.next.loc - driver.loc
        # fix wraparound
        if dist < 0:
            dist += self.length
        return dist
    
    def set_odometers(self):
        return [driver.set_odometer()
                for driver in self.drivers] 
    
    def read_odometers(self):
        return np.mean([driver.read_odometer()
                        for driver in self.drivers])

# %% [markdown]
# The `HighwayViewer` is based on the Cell2DViewer (although it does not draw a grid).

# %%
class HighwayViewer(Cell2DViewer):
    """Generates visualization and animation of SugarScape."""
    
    def draw(self, grid=False):
        """Draws the array and any other elements.
        
        grid: boolean, whether to draw grid lines
        """
        self.draw_drivers()
        
        plt.axis('off')
        plt.axis('equal')
        plt.xlim([-1.05, 1.05])
        plt.ylim([-1.05, 1.05])

    def draw_drivers(self):
        """Plots the drivers.
        """
        drivers = self.viewee.drivers
        xs, ys = self.get_coords(drivers)
        self.points = plt.plot(xs, ys, 'bs', markersize=10, alpha=0.7)[0]
        
        stopped = [driver for driver in self.viewee.drivers 
                  if driver.speed==0]
        xs, ys = self.get_coords(stopped)
        xs *= 0.9
        ys *= 0.9
        self.stopped = plt.plot(xs, ys, 'r^', markersize=12, alpha=0.7)[0]
        
    def animate_func(self, i):
        """Draws one frame of the animation."""
        if i > 0:
            self.step()
        drivers = self.viewee.drivers
        xs, ys = self.get_coords(drivers)
        self.points.set_data(np.array([xs, ys]))
        
        stopped = [driver for driver in self.viewee.drivers 
                  if driver.speed==0]
        xs, ys = self.get_coords(stopped)
        self.stopped.set_data(np.array([xs, ys]) * 0.9)
        return self.points,
    
    def get_coords(self, drivers):
        """Gets the coordinates of the drivers.
        
        Transforms from (row, col) to (x, y).
        
        returns: tuple of sequences, (xs, ys)
        """
        scale = 2 * np.pi / self.viewee.length
        
        locs = np.array([driver.loc for driver in drivers])
        xs = np.cos(locs * scale)
        ys = np.sin(locs * scale)
        return xs, ys

# %% [markdown]
# Make the animation:

# %%
highway = Highway(30, eps=0.02)
viewer = HighwayViewer(highway)
anim = viewer.animate(frames=600, interval=200)

# %%
anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imga1ce22bd6d054aaa8fc123cb302cf59b">
#     <br>
#     <input id="_anim_slidera1ce22bd6d054aaa8fc123cb302cf59b" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anima1ce22bd6d054aaa8fc123cb302cf59b.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anima1ce22bd6d054aaa8fc123cb302cf59b.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anima1ce22bd6d054aaa8fc123cb302cf59b.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anima1ce22bd6d054aaa8fc123cb302cf59b.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anima1ce22bd6d054aaa8fc123cb302cf59b.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anima1ce22bd6d054aaa8fc123cb302cf59b.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anima1ce22bd6d054aaa8fc123cb302cf59b.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anima1ce22bd6d054aaa8fc123cb302cf59b.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anima1ce22bd6d054aaa8fc123cb302cf59b.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anima1ce22bd6d054aaa8fc123cb302cf59b.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selecta1ce22bd6d054aaa8fc123cb302cf59b" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imga1ce22bd6d054aaa8fc123cb302cf59b";
#     var slider_id = "_anim_slidera1ce22bd6d054aaa8fc123cb302cf59b";
#     var loop_select_id = "_anim_loop_selecta1ce22bd6d054aaa8fc123cb302cf59b";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvNQv5yAAABmBJREFUeJzt3cGt4joAQNEw+l2woSYKpSY68V/O\
# k95iAgoi1z5njVAiHF3hxM5ljDE2AIj58+0DAIB3CBgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAk\
# YAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKA\
# AZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASf99+wCg6H7ftufz35+73bbt\
# 8fjed8LMBAze8Hxu2/W673Pf/E6YmSlEAJIEDIAkAQMgyT0wprb6gxGrnz9zEzCmtvqDEaufP3Mz\
# hQhAkoABkCRgACS5BwZvuN32Pxzxze+EmQkYvOETT+x5ChBeYwoRgCQBAyDJFCKnY/HtefltOBMB\
# 43SOXHy7+oMRR5+/hdGciYAxtdX/Bax+/szNPTAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyDJOjBO\
# Z/XFx2fmt+FMLmOM8e2DAIBX+QfGYeyTx17GCkcQMA5jnzz2MlY4goc4AEgSMACSBAyAJAEDIEnA\
# AEgSMACSBAyAJAEDIMlCZg5jnzz2MlY4gr0QAUgyhQhAkoABkCRgACQJGABJnkLkF+9q4qyMTX4S\
# MH7xribOytjkJ1OIACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkGQhM794VxNnZWzyk/eBAZBk\
# ChGAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEiykHkRXsXOaoz5+QnYIryKndUY8/MzhQhAkoABkCRg\
# ACQJGABJAgZAkoABkCRgACQJGABJFjIvwqvYWY0xP7/LGGN8+yAA4FWmEAFIEjAAkgQMgCQBAyBJ\
# wABIEjAAkgQMgCQBAyBJwABIspXURO73/VvnPB6fPho4L9fKHARsIs/ntl2v+z4HK3OtzMEUIgBJ\
# AgZAkoABkCRgACQJGABJAgZAkoABkCRgACRZyDyR223/7gKwMtfKHC5jjPHtgwCAV5lCBCBJwABI\
# EjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyDJVlITuN/3b4vzeHz6aKDDtdMmYBN4Prftet33OeAv\
# 106bKUQAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIspB5Arfb/t0EgL9cO22XMcb49kEAwKtM\
# IQKQJGAAJAkYAEkCBkCSgAGQJGAAJAkYAEkCBkCSgAGQJGAAJNkLcSL3+/593R6PTx8NnJdrZQ4C\
# NpHnc9uu132fg5W5VuZgChGAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEgSMACSLGSeyO22f3cBWJlr\
# ZQ6XMcb49kEAwKtMIQKQJGAAJAkYAEkCBkCSgAGQJGAAJAkYAEkCBkCSnTgWcb/v33ng8fj00cDn\
# GfPzE7BFPJ/bdr3u+xzMwJifnylEAJIEDIAkAQMgScAASBIwAJIEDIAkAQMgScAASLKQeRG32/5d\
# CWAGxvz8LmOM8e2DAIBXmUIEIEnAAEgSMACSBAyAJAEDIEnAAEgSMACSLGTmF69i56yMTX4SMH7x\
# KnbOytjkJ1OIACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkGQhM794FTtnZWzy02WMMb59EADw\
# KlOIACQJGABJAgZAkoABkOQpRA7jXU3sZaxwBAHjMN7VxF7GCkcwhQhAkoABkCRgACQJGABJAgZA\
# koABkCRgACQJGABJFjJzGO9qYi9jhSN4HxgASaYQAUgyhcjp2Oj1vPw2nImAcTo2ej0vvw1nYgoR\
# gCQBAyBJwABIEjAAkgQMgCQBAyBJwABIsg6Mqa2+8Hb182duAsbpHLnR6+oLb48+f

# %% [markdown]
# And generate the figure:

# %%
RandomSeed(22)

highway = Highway(30, eps=0.02)
viewer = HighwayViewer(highway)

thinkplot.preplot(cols=3)
for i in range(16):
    highway.step()
viewer.draw()

thinkplot.subplot(2)
for i in range(1):
    highway.step()
viewer.draw()

thinkplot.subplot(3)
for i in range(1):
    highway.step()
viewer.draw()

thinkplot.tight_layout()
thinkplot.save('chap10-1')
# Out:
# Writing chap10-1.pdf
# Writing chap10-1.png

# %% [markdown]
# Explore the relationship between `eps` and average speed.

# %%
def run_simulation(eps, constructor=Driver, iters=100):
    res = []
    for n in range(5, 100, 5):
        highway = Highway(n, eps=eps, constructor=constructor)
        for i in range(iters):
            highway.step()

        highway.set_odometers()
        for i in range(iters):
            highway.step()

        res.append((n, highway.read_odometers() / iters))
    
    return np.transpose(res)

# %% [markdown]
# Generate the figure:

# %%
RandomSeed(20)

for eps in [0.0, 0.001, 0.01]:
    xs, ys = run_simulation(eps)
    thinkplot.plot(xs, ys, label='eps=%g' % eps)
    
thinkplot.config(xlabel='Number of cars',
                 ylabel='Average speed',
                 xlim=[0, 100], ylim=[0, 42])

thinkplot.save('chap10-2')
# Out:
# Writing chap10-2.pdf
# Writing chap10-2.png

# %% [markdown]
# **Exercise:** In the traffic jam simulation, define a class, `BetterDriver`,
# that inherits from `Driver` and overrides `choose_acceleration`.
# See if you can define driving rules that do better than the basic
# implementation in `Driver`.  You might try to achieve higher
# average speed, or a lower number of collisions.

# %%
# Not actually a solution yet; just playing around.

class BetterDriver(Driver):
    
    def choose_acceleration(self, d):
        if self.speed < 20:
            return 1
        else:
            return 0

# %%
for constructor in [Driver, BetterDriver]:
    xs, ys = run_simulation(eps=0.0, constructor=constructor)
    thinkplot.plot(xs, ys, label=constructor.__name__)
    
thinkplot.config(xlabel='Number of cars',
                 ylabel='Average speed',
                 xlim=[0, 100], ylim=[0, 42])
